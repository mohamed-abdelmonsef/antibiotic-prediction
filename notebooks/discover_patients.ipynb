# %%
data_path = '../src/data/'

file_path = data_path + 'complete_microbiology_cultures_data.csv'

# %%
import pandas as pd

# %%
df = pd.read_csv(file_path)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474243 entries, 0 to 474242
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_proc_id_coded  474243 non-null  int64
#  1   culture_description  474243 non-null  object
#  2   antibiotic           474243 non-null  object
#  3   age                  474243 non-null  object
#  4   gender               474218 non-null  float64
#  5   median_heartrate     473511 non-null  float64
#  6   median_resprate      465406 non-null  float64
#  7   median_temp          466756 non-null  float64
#  8   median_sysbp         471344 non-null  float64
#  9   median_diasbp        471148 non-null  float64
#  10  median_wbc           465625 non-null  float64
#  11  median_hgb           466581 non-null  float64
#  12  median_plt           466098 non-null  float64
#  13  median_na            465764 non-null  float64
# ...

# %%
df.tail()
# Out:
#         order_proc_id_coded culture_description            antibiotic  \
# 474238            606338977               URINE         Ciprofloxacin
# 474239            523271451               URINE         Ciprofloxacin
# 474240            510400314               BLOOD         Ciprofloxacin
# 474241            437706157               URINE         Ciprofloxacin
# 474242            780686388               URINE  Ampicillin/Sulbactam
#
#                 age  gender  median_heartrate  median_resprate  median_temp  \
# 474238  35-44 years     0.0              77.0             16.0         97.9
# 474239  75-84 years     0.0              79.0             16.0         98.5
# 474240  25-34 years     0.0              96.0             18.0         98.2
# 474241     above 90     0.0              98.0             18.0         98.0
# 474242     above 90     0.0              62.0             18.0         97.1
#
#         median_sysbp  median_diasbp  median_wbc  median_hgb  median_plt  \
# ...

# %%
# check rows of order_proc_id_coded in (780686388, 510400314, 510400315)
lst = df[df['order_proc_id_coded'].isin([780686388, 437706157, 681936151])]
lst.shape
# Out:
# (73, 17)

# %%
lst.to_csv(data_path + 'filtered_cultures.csv', index=False)

# %%
lst[lst['order_proc_id_coded']==681936151]
# Out:
#         order_proc_id_coded culture_description  \
# 4                 681936151               URINE
# 3388              681936151               URINE
# 14913             681936151               URINE
# 18120             681936151               URINE
# 20576             681936151               URINE
# 23956             681936151               URINE
# 45697             681936151               URINE
# 110028            681936151               URINE
# 112094            681936151               URINE
# 144683            681936151               URINE
# 185071            681936151               URINE
# 189074            681936151               URINE
# 241941            681936151               URINE
# 251986            681936151               URINE
# 257103            681936151               URINE
# 287421            681936151               URINE
# 302863            681936151               URINE
# 314956            681936151               URINE
# ...

# %%
df['age'].unique()
# Out:
# array(['75-84 years', '65-74 years', '55-64 years', '35-44 years',
#        '45-54 years', 'above 90', '25-34 years', '85-89 years',
#        '18-24 years'], dtype=object)

# %%
df[df['antibiotic']=='Colistin']
# Out:
#         order_proc_id_coded culture_description antibiotic          age  \
# 3638              438526036         RESPIRATORY   Colistin  25-34 years
# 24246             357305056         RESPIRATORY   Colistin  25-34 years
# 25251             432244315         RESPIRATORY   Colistin  35-44 years
# 30947             339537616         RESPIRATORY   Colistin  18-24 years
# 38175             387095511         RESPIRATORY   Colistin  25-34 years
# 57398             330592991         RESPIRATORY   Colistin  45-54 years
# 61837             362284980         RESPIRATORY   Colistin  25-34 years
# 62893             339537616         RESPIRATORY   Colistin  18-24 years
# 68016             397779317         RESPIRATORY   Colistin  45-54 years
# 72192             446009052         RESPIRATORY   Colistin  18-24 years
# 72716             442606608         RESPIRATORY   Colistin  25-34 years
# 77537             366661583         RESPIRATORY   Colistin  25-34 years
# ...

# %%
ff = df[df['order_proc_id_coded']==339537616]

# %%
ff['antibiotic'].unique()
# Out:
# array(['Trimethoprim/Sulfamethoxazole', 'Colistin', 'Vancomycin',
#        'Tobramycin', 'Linezolid', 'Piperacillin', 'Ceftazidime',
#        'Aztreonam', 'Ticarcillin', 'Tetracycline', 'Imipenem',
#        'Gentamicin', 'Amikacin'], dtype=object)

# %%
(df[df['order_proc_id_coded']==339537616])['antibiotic'].unique()
# Out:
# array(['Trimethoprim/Sulfamethoxazole', 'Colistin', 'Vancomycin',
#        'Tobramycin', 'Linezolid', 'Piperacillin', 'Ceftazidime',
#        'Aztreonam', 'Ticarcillin', 'Tetracycline', 'Imipenem',
#        'Gentamicin', 'Amikacin'], dtype=object)

# %%
df[df['order_proc_id_coded']==339537616]
# Out:
#         order_proc_id_coded culture_description  \
# 21772             339537616         RESPIRATORY
# 30947             339537616         RESPIRATORY
# 62893             339537616         RESPIRATORY
# 99134             339537616         RESPIRATORY
# 104046            339537616         RESPIRATORY
# 136260            339537616         RESPIRATORY
# 149143            339537616         RESPIRATORY
# 161101            339537616         RESPIRATORY
# 171645            339537616         RESPIRATORY
# 172802            339537616         RESPIRATORY
# 204503            339537616         RESPIRATORY
# 213793            339537616         RESPIRATORY
# 247978            339537616         RESPIRATORY
# 270629            339537616         RESPIRATORY
# 352486            339537616         RESPIRATORY
#
#                            antibiotic          age  gender  median_heartrate  \
# 21772   Trimethoprim/Sulfamethoxazole  18-24 years     1.0             125.0
# ...
